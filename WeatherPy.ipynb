# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
#pip install census

# %%
#!pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
 # Empty list for holding the latitude and longitude combinations
lat_lngs = []

 # Empty list for holding the cities names
cities = []

 # Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

 # Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

#If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 572

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
 # Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key# YOUR CODE HERE

# Define an empty list to fetch the weather data for each city
city_weather = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city# YOUR CODE HERE
  
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_data = requests.get(city_url).json()
        # YOUR CODE HERE

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_data['coord']["lat"]# YOUR CODE HERE
        city_lng = city_data['coord']["lon"]# YOUR CODE HERE
        city_max_temp = city_data['main']["temp_max"]# YOUR CODE HERE
        city_humidity = city_data['main']["humidity"]# YOUR CODE HERE
        city_clouds = city_data['clouds']["all"]# YOUR CODE HERE
        city_wind = city_data['wind']["speed"]# YOUR CODE HERE
        city_country = city_data['sys']["country"]# YOUR CODE HERE
        city_date = city_data['dt']# YOUR CODE HERE

        # Append the City information into city_data list
        city_weather.append({"City": city,
                          "lat": city_lat,
                          "lon": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | edinburgh of the seven seas
# Processing Record 2 of Set 1 | margate
# Processing Record 3 of Set 1 | hawaiian paradise park
# Processing Record 4 of Set 1 | cargados carajos
# City not found. Skipping...
# Processing Record 5 of Set 1 | aripuana
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | puerto armuelles
# Processing Record 8 of Set 1 | catarman
# Processing Record 9 of Set 1 | nar'yan-mar
# Processing Record 10 of Set 1 | sitka
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | mount pearl
# Processing Record 13 of Set 1 | waitangi
# Processing Record 14 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 15 of Set 1 | grytviken
# Processing Record 16 of Set 1 | puerto baquerizo moreno
# Processing Record 17 of Set 1 | kailua-kona
# Processing Record 18 of Set 1 | bethel
# Processing Record 19 of Set 1 | enewetak
# Processing Record 20 of Set 1 | nuuk
# Processing Record 21 of Set 1 | fortuna
# Processing Record 22 of Set 1 | bilibino
# Processing Record 23 of Set 1 | puerto natales
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | pechora
# Processing Record 27 of Set 1 | haiku-pauwela
# Processing Record 28 of Set 1 | chui
# Processing Record 29 of Set 1 | luanda
# Processing Record 30 of Set 1 | kodiak
# Processing Record 31 of Set 1 | santa catalina
# Processing Record 32 of Set 1 | dawson creek
# Processing Record 33 of Set 1 | arno
# Processing Record 34 of Set 1 | west island
# Processing Record 35 of Set 1 | aasiaat
# Processing Record 36 of Set 1 | den burg
# Processing Record 37 of Set 1 | dudinka
# Processing Record 38 of Set 1 | tateyama
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | touros
# Processing Record 41 of Set 1 | uturoa
# Processing Record 42 of Set 1 | klyuchi
# Processing Record 43 of Set 1 | college
# Processing Record 44 of Set 1 | vadso
# Processing Record 45 of Set 1 | ravar
# Processing Record 46 of Set 1 | kencong
# Processing Record 47 of Set 1 | benghazi
# Processing Record 48 of Set 1 | bengkulu
# Processing Record 49 of Set 1 | ilulissat
# Processing Record 50 of Set 1 | lompoc
# Processing Record 0 of Set 2 | thompson
# Processing Record 1 of Set 2 | narrabri
# Processing Record 2 of Set 2 | axim
# Processing Record 3 of Set 2 | papatowai
# Processing Record 4 of Set 2 | tidjikja
# Processing Record 5 of Set 2 | iqaluit
# Processing Record 6 of Set 2 | igarka
# Processing Record 7 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | shache
# Processing Record 10 of Set 2 | kurchatov
# Processing Record 11 of Set 2 | adamstown
# Processing Record 12 of Set 2 | khovd
# Processing Record 13 of Set 2 | kudat
# Processing Record 14 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 15 of Set 2 | ushuaia
# Processing Record 16 of Set 2 | dien bien phu
# Processing Record 17 of Set 2 | kamloops
# Processing Record 18 of Set 2 | ascension
# Processing Record 19 of Set 2 | port-aux-francais
# Processing Record 20 of Set 2 | tiksi
# Processing Record 21 of Set 2 | gizo
# Processing Record 22 of Set 2 | fale old settlement
# Processing Record 23 of Set 2 | saldanha
# Processing Record 24 of Set 2 | la romana
# Processing Record 25 of Set 2 | aleg
# Processing Record 26 of Set 2 | wailua homesteads
# Processing Record 27 of Set 2 | saint-louis
# Processing Record 28 of Set 2 | toga village
# City not found. Skipping...
# Processing Record 29 of Set 2 | longyearbyen
# Processing Record 30 of Set 2 | vorgashor
# Processing Record 31 of Set 2 | muroto-misakicho
# Processing Record 32 of Set 2 | ugoofaaru
# Processing Record 33 of Set 2 | bodo
# Processing Record 34 of Set 2 | nyagan
# Processing Record 35 of Set 2 | zeya
# Processing Record 36 of Set 2 | fuvahmulah
# City not found. Skipping...
# Processing Record 37 of Set 2 | al muwayh
# Processing Record 38 of Set 2 | stanley
# Processing Record 39 of Set 2 | mount isa
# Processing Record 40 of Set 2 | heihe
# Processing Record 41 of Set 2 | sinabang
# Processing Record 42 of Set 2 | vanimo
# Processing Record 43 of Set 2 | kapuskasing
# Processing Record 44 of Set 2 | khandyga
# Processing Record 45 of Set 2 | kuzovatovo
# Processing Record 46 of Set 2 | whitehorse
# Processing Record 47 of Set 2 | codrington
# Processing Record 48 of Set 2 | utrik
# Processing Record 49 of Set 2 | badger
# Processing Record 0 of Set 3 | isafjordur
# Processing Record 1 of Set 3 | sogndal
# Processing Record 2 of Set 3 | margaret river
# Processing Record 3 of Set 3 | longboat key
# Processing Record 4 of Set 3 | strezhevoy
# Processing Record 5 of Set 3 | hermanus
# Processing Record 6 of Set 3 | uvira
# Processing Record 7 of Set 3 | port elizabeth
# Processing Record 8 of Set 3 | carnarvon
# Processing Record 9 of Set 3 | maragogi
# Processing Record 10 of Set 3 | lisala
# Processing Record 11 of Set 3 | fortaleza
# Processing Record 12 of Set 3 | udachny
# Processing Record 13 of Set 3 | marathon
# Processing Record 14 of Set 3 | kuressaare
# Processing Record 15 of Set 3 | luderitz
# Processing Record 16 of Set 3 | cabo san lucas
# Processing Record 17 of Set 3 | bubaque
# Processing Record 18 of Set 3 | mana
# Processing Record 19 of Set 3 | nili
# Processing Record 20 of Set 3 | qandala
# Processing Record 21 of Set 3 | afaahiti
# Processing Record 22 of Set 3 | susuman
# Processing Record 23 of Set 3 | remire-montjoly
# Processing Record 24 of Set 3 | invercargill
# Processing Record 25 of Set 3 | anadyr
# Processing Record 26 of Set 3 | musan-up
# Processing Record 27 of Set 3 | karoi
# Processing Record 28 of Set 3 | hadibu
# Processing Record 29 of Set 3 | gurlan
# Processing Record 30 of Set 3 | ancud
# Processing Record 31 of Set 3 | carutapera
# Processing Record 32 of Set 3 | greenville
# Processing Record 33 of Set 3 | fort dodge
# Processing Record 34 of Set 3 | puerto ayora
# Processing Record 35 of Set 3 | gokwe
# Processing Record 36 of Set 3 | mabaruma
# Processing Record 37 of Set 3 | macapa
# Processing Record 38 of Set 3 | marsabit
# Processing Record 39 of Set 3 | belen
# Processing Record 40 of Set 3 | atafu village
# Processing Record 41 of Set 3 | calama
# Processing Record 42 of Set 3 | timbuktu
# Processing Record 43 of Set 3 | qoryooley
# Processing Record 44 of Set 3 | blackmans bay
# Processing Record 45 of Set 3 | bovalino
# Processing Record 46 of Set 3 | mata-utu
# Processing Record 47 of Set 3 | okha
# Processing Record 48 of Set 3 | tura
# Processing Record 49 of Set 3 | hiratacho
# Processing Record 0 of Set 4 | port augusta
# Processing Record 1 of Set 4 | coquimbo
# Processing Record 2 of Set 4 | handan
# Processing Record 3 of Set 4 | gobabis
# Processing Record 4 of Set 4 | lebu
# Processing Record 5 of Set 4 | fort bragg
# Processing Record 6 of Set 4 | kiunga
# Processing Record 7 of Set 4 | lihue
# Processing Record 8 of Set 4 | yuzhno-kurilsk
# Processing Record 9 of Set 4 | port mathurin
# Processing Record 10 of Set 4 | nehe
# Processing Record 11 of Set 4 | contamana
# Processing Record 12 of Set 4 | port saint john's
# Processing Record 13 of Set 4 | arraial do cabo
# Processing Record 14 of Set 4 | avarua
# Processing Record 15 of Set 4 | east london
# Processing Record 16 of Set 4 | labrador city
# Processing Record 17 of Set 4 | bathurst
# Processing Record 18 of Set 4 | mount gambier
# Processing Record 19 of Set 4 | port lincoln
# Processing Record 20 of Set 4 | jabat
# Processing Record 21 of Set 4 | koneurgench
# City not found. Skipping...
# Processing Record 22 of Set 4 | thunder bay
# Processing Record 23 of Set 4 | chachersk
# Processing Record 24 of Set 4 | port sudan
# Processing Record 25 of Set 4 | kaihua
# Processing Record 26 of Set 4 | olyokminsk
# Processing Record 27 of Set 4 | nemuro
# Processing Record 28 of Set 4 | usinsk
# Processing Record 29 of Set 4 | bikenibeu village
# Processing Record 30 of Set 4 | ceerigaabo
# Processing Record 31 of Set 4 | nema
# Processing Record 32 of Set 4 | la passe
# Processing Record 33 of Set 4 | 'anah
# City not found. Skipping...
# Processing Record 34 of Set 4 | qalat
# Processing Record 35 of Set 4 | sao lourenco
# Processing Record 36 of Set 4 | maralal
# Processing Record 37 of Set 4 | hayma'
# City not found. Skipping...
# Processing Record 38 of Set 4 | beijing
# Processing Record 39 of Set 4 | kununurra
# Processing Record 40 of Set 4 | maintirano
# Processing Record 41 of Set 4 | sona
# Processing Record 42 of Set 4 | nagqu
# Processing Record 43 of Set 4 | keminmaa
# Processing Record 44 of Set 4 | tromso
# Processing Record 45 of Set 4 | weno
# Processing Record 46 of Set 4 | patterson
# Processing Record 47 of Set 4 | antsiranana
# Processing Record 48 of Set 4 | mahina
# Processing Record 49 of Set 4 | alofi
# Processing Record 0 of Set 5 | hammerfest
# Processing Record 1 of Set 5 | vila franca do campo
# Processing Record 2 of Set 5 | saudarkrokur
# Processing Record 3 of Set 5 | northam
# Processing Record 4 of Set 5 | tortoli
# Processing Record 5 of Set 5 | ishigaki
# Processing Record 6 of Set 5 | holualoa
# Processing Record 7 of Set 5 | new norfolk
# Processing Record 8 of Set 5 | staraya mayna
# Processing Record 9 of Set 5 | paidha
# Processing Record 10 of Set 5 | kourou
# Processing Record 11 of Set 5 | la'ie
# Processing Record 12 of Set 5 | ordos
# City not found. Skipping...
# Processing Record 13 of Set 5 | halba
# Processing Record 14 of Set 5 | santa maria del oro
# Processing Record 15 of Set 5 | lembar
# City not found. Skipping...
# Processing Record 16 of Set 5 | gorokhovets
# Processing Record 17 of Set 5 | gallup
# Processing Record 18 of Set 5 | saipan
# Processing Record 19 of Set 5 | greymouth
# Processing Record 20 of Set 5 | ghugus
# Processing Record 21 of Set 5 | bogoroditsk
# Processing Record 22 of Set 5 | pato branco
# Processing Record 23 of Set 5 | hamilton
# Processing Record 24 of Set 5 | pisco
# Processing Record 25 of Set 5 | grantsville
# Processing Record 26 of Set 5 | mar del plata
# Processing Record 27 of Set 5 | zemio
# Processing Record 28 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 29 of Set 5 | hola
# Processing Record 30 of Set 5 | hasaki
# Processing Record 31 of Set 5 | rio grande
# Processing Record 32 of Set 5 | jamestown
# Processing Record 33 of Set 5 | sisimiut
# Processing Record 34 of Set 5 | smithers
# Processing Record 35 of Set 5 | rabaul
# Processing Record 36 of Set 5 | alice springs
# Processing Record 37 of Set 5 | newman
# Processing Record 38 of Set 5 | piterka
# Processing Record 39 of Set 5 | ribeira grande
# Processing Record 40 of Set 5 | sal rei
# Processing Record 41 of Set 5 | spanish wells
# Processing Record 42 of Set 5 | nouadhibou
# Processing Record 43 of Set 5 | somcuta mare
# Processing Record 44 of Set 5 | puerto deseado
# Processing Record 45 of Set 5 | al kharijah
# Processing Record 46 of Set 5 | magadan
# Processing Record 47 of Set 5 | brisas de zicatela
# Processing Record 48 of Set 5 | xilin hot
# Processing Record 49 of Set 5 | prescott
# Processing Record 0 of Set 6 | masuguru
# Processing Record 1 of Set 6 | tolanaro
# Processing Record 2 of Set 6 | talnakh
# Processing Record 3 of Set 6 | whangarei
# Processing Record 4 of Set 6 | taroa
# Processing Record 5 of Set 6 | aylmer
# Processing Record 6 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 7 of Set 6 | bracebridge
# Processing Record 8 of Set 6 | severo-yeniseyskiy
# Processing Record 9 of Set 6 | cadale
# Processing Record 10 of Set 6 | vilyuchinsk
# Processing Record 11 of Set 6 | hithadhoo
# Processing Record 12 of Set 6 | crane
# Processing Record 13 of Set 6 | bodaybo
# Processing Record 14 of Set 6 | alcochete
# Processing Record 15 of Set 6 | ahau
# City not found. Skipping...
# Processing Record 16 of Set 6 | mount pleasant
# Processing Record 17 of Set 6 | michurinsk
# Processing Record 18 of Set 6 | xinguara
# City not found. Skipping...
# Processing Record 19 of Set 6 | hendek
# Processing Record 20 of Set 6 | iskateley
# Processing Record 21 of Set 6 | kavieng
# Processing Record 22 of Set 6 | el charco
# Processing Record 23 of Set 6 | cogealac
# Processing Record 24 of Set 6 | burang
# Processing Record 25 of Set 6 | n'diareme limamoulaye
# City not found. Skipping...
# Processing Record 26 of Set 6 | flying fish cove
# Processing Record 27 of Set 6 | keflavik
# Processing Record 28 of Set 6 | abepura
# Processing Record 29 of Set 6 | hatert
# City not found. Skipping...
# Processing Record 30 of Set 6 | namibe
# Processing Record 31 of Set 6 | assinovskaya
# Processing Record 32 of Set 6 | gidole
# Processing Record 33 of Set 6 | mitu
# Processing Record 34 of Set 6 | inirida
# Processing Record 35 of Set 6 | myitkyina
# Processing Record 36 of Set 6 | kupang
# Processing Record 37 of Set 6 | ta`u
# Processing Record 38 of Set 6 | san jose de gracia
# Processing Record 39 of Set 6 | olonkinbyen
# Processing Record 40 of Set 6 | jonuta
# Processing Record 41 of Set 6 | sao tome
# Processing Record 42 of Set 6 | mayqayyng
# Processing Record 43 of Set 6 | lerwick
# Processing Record 44 of Set 6 | ar ruways
# Processing Record 45 of Set 6 | al jawf
# Processing Record 46 of Set 6 | sampit
# Processing Record 47 of Set 6 | kolonia
# Processing Record 48 of Set 6 | port-cartier
# Processing Record 49 of Set 6 | semera
# Processing Record 0 of Set 7 | caleta olivia
# Processing Record 1 of Set 7 | uyuni
# Processing Record 2 of Set 7 | port pirie
# Processing Record 3 of Set 7 | chifeng
# Processing Record 4 of Set 7 | inhambane
# Processing Record 5 of Set 7 | belyy yar
# Processing Record 6 of Set 7 | ulladulla
# Processing Record 7 of Set 7 | coahuayana de hidalgo
# Processing Record 8 of Set 7 | dergachi
# Processing Record 9 of Set 7 | akureyri
# Processing Record 10 of Set 7 | petrila
# Processing Record 11 of Set 7 | marsa alam
# Processing Record 12 of Set 7 | trairi
# Processing Record 13 of Set 7 | geraldton
# Processing Record 14 of Set 7 | minas de marcona
# Processing Record 15 of Set 7 | colonia
# Processing Record 16 of Set 7 | waingapu
# Processing Record 17 of Set 7 | deolali
# Processing Record 18 of Set 7 | kenai
# Processing Record 19 of Set 7 | el bauga
# Processing Record 20 of Set 7 | novo brdo
# Processing Record 21 of Set 7 | moscow
# Processing Record 22 of Set 7 | anapa
# Processing Record 23 of Set 7 | gijang
# Processing Record 24 of Set 7 | enoch
# Processing Record 25 of Set 7 | dunedin
# Processing Record 26 of Set 7 | aykhal
# Processing Record 27 of Set 7 | imbituba
# Processing Record 28 of Set 7 | richfield
# Processing Record 29 of Set 7 | ulundi
# Processing Record 30 of Set 7 | malango
# Processing Record 31 of Set 7 | cable beach
# City not found. Skipping...
# Processing Record 32 of Set 7 | kwangyang
# Processing Record 33 of Set 7 | villa gesell
# Processing Record 34 of Set 7 | petrozavodsk
# Processing Record 35 of Set 7 | novonikolayevskiy
# Processing Record 36 of Set 7 | mukalla
# Processing Record 37 of Set 7 | san matias
# Processing Record 38 of Set 7 | qaqortoq

# %%
# Convert the cities weather data into a Pandas DataFrame

import pandas as pd
city_weather = pd.read_csv("output_data/cities.csv")


city_weather.count()
# Out:
# City_ID       577
# City_ID.2     577
# City_ID.1     577
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       574
# Date          577
# dtype: int64

# %%
# Display sample data

city_weather.head()
# Out:
#    City_ID  City_ID.2  City_ID.1         City      Lat       Lng  Max Temp  \
# 0        0          0          0         faya  18.3851   42.4509     22.06
# 1        1          1          1      farsund  58.0948    6.8047     13.30
# 2        2          2          2  new norfolk -42.7826  147.0587     11.72
# 3        3          3          3    jamestown  42.0970  -79.2353      5.77
# 4        4          4          4      lanzhou  36.0564  103.7922     14.53
#
#    Humidity  Cloudiness  Wind Speed Country        Date
# 0        35          21        2.60      SA  1666108228
# 1       100           0        7.65      NO  1666108228
# 2        58          12        1.34      AU  1666108230
# 3        77         100        9.77      US  1666107934
# 4        48          59        1.20      CN  1666108230

# %%
# Export the City_Data into a csv
city_weather.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_weather = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_weather.head()
# Out:
#          City_ID.3  City_ID.2  City_ID.1         City      Lat       Lng  \
# City_ID
# 0                0          0          0         faya  18.3851   42.4509
# 1                1          1          1      farsund  58.0948    6.8047
# 2                2          2          2  new norfolk -42.7826  147.0587
# 3                3          3          3    jamestown  42.0970  -79.2353
# 4                4          4          4      lanzhou  36.0564  103.7922
#
#          Max Temp  Humidity  Cloudiness  Wind Speed Country        Date
# City_ID
# 0           22.06        35          21        2.60      SA  1666108228
# 1           13.30       100           0        7.65      NO  1666108228
# 2           11.72        58          12        1.34      AU  1666108230
# 3            5.77        77         100        9.77      US  1666107934
# 4           14.53        48          59        1.20      CN  1666108230

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
import matplotlib.pyplot as plt
import pandas as pd
# YOUR CODE HERE
plt.scatter(city_weather['Lat'], city_weather['Max Temp'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Max Temperature")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)




# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_weather['Lat'], city_weather['Humidity'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)


# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_weather['Lat'], city_weather['Cloudiness'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)



# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_weather['Lat'], city_weather['Wind Speed'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)



# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
from scipy import stats
# Define a function to create Linear Regression plots
x_values = city_weather['Lat']
y_values = city_weather['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,260),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:-0.606154803037973

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_weather[city_weather['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#          City_ID.3  City_ID.2  City_ID.1       City      Lat       Lng  \
# City_ID
# 0                0          0          0       faya  18.3851   42.4509
# 1                1          1          1    farsund  58.0948    6.8047
# 3                3          3          3  jamestown  42.0970  -79.2353
# 4                4          4          4    lanzhou  36.0564  103.7922
# 6                6          6          6     albany  42.6001  -73.9662
#
#          Max Temp  Humidity  Cloudiness  Wind Speed Country        Date
# City_ID
# 0           22.06        35          21        2.60      SA  1666108228
# 1           13.30       100           0        7.65      NO  1666108228
# 3            5.77        77         100        9.77      US  1666107934
# 4           14.53        48          59        1.20      CN  1666108230
# 6           10.36        74          29        2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_weather[city_weather['Lat'] > 0]
# Display sample data
southern_hemi_df.head()
# Out:
#          City_ID.3  City_ID.2  City_ID.1       City      Lat       Lng  \
# City_ID
# 0                0          0          0       faya  18.3851   42.4509
# 1                1          1          1    farsund  58.0948    6.8047
# 3                3          3          3  jamestown  42.0970  -79.2353
# 4                4          4          4    lanzhou  36.0564  103.7922
# 6                6          6          6     albany  42.6001  -73.9662
#
#          Max Temp  Humidity  Cloudiness  Wind Speed Country        Date
# City_ID
# 0           22.06        35          21        2.60      SA  1666108228
# 1           13.30       100           0        7.65      NO  1666108228
# 3            5.77        77         100        9.77      US  1666107934
# 4           14.53        48          59        1.20      CN  1666108230
# 6           10.36        74          29        2.10      US  1666108231

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
import pandas as pd
from scipy.stats import linregress

# %%
# Linear regression on Northern Hemisphere


city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")
northern_hemi_df = city_data_df [city_data_df['Lat'] < 0]
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(400,50),fontsize=15,color="red") 
plt.xlabel('Northern Latitude')
plt.ylabel('Max Temperature')
print(f"The r-squared is: {rvalue**2}")
plt.show
# Out:
# The r-squared is: 0.4121057168607252
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

city_weather = pd.read_csv("output_data/cities.csv", index_col="City_ID")
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,295),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Max Temperature')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:-0.8462548186825364

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,50),fontsize=15,color="red") 
plt.xlabel('Northern Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show
# Out:
# The r-squared is: 0.0002808747046324618
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Southern Hemisphere
# YOUR CODE HERE

city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(400,50),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Humidity') 
print(f"The r-squared is: {rvalue**2}")
plt.show
# Out:
# The r-squared is: 0.024026517125811043
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Norhern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(400,50),fontsize=15,color="red") 
plt.xlabel('Northern Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show
# Out:
# The r-squared is: 0.020567354299943663
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,55),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Humidity')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.2385317912939407

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,8),fontsize=15,color="red")
plt.xlabel('Northern Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:-0.24947753546264592

# %%
# Southern Hemisphere
# YOUR CODE HERE
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,55),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.1743466729090334

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
